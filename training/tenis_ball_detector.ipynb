# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------- ----------------------------- 41.0/158.3 kB 2.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 41.0/158.3 kB 2.0 MB/s eta 0:00:01
#    --------------------------- ---------- 112.6/158.3 kB 939.4 kB/s eta 0:00:01
#    --------------------------- ---------- 112.6/158.3 kB 939.4 kB/s eta 0:00:01
#    ------------------------------------ - 153.6/158.3 kB 657.6 kB/s eta 0:00:01
#    -------------------------------------- 158.3/158.3 kB 679.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    ------------------------------------ --- 163.8/178.7 kB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 163.8/178.7 kB 9.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# ### Get Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CYymMscGDSUybAutx38n")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:01<00:00, 768.54it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
            "tennis-ball-detection-6/tennis-ball-detection-6/train")

shutil.move("tennis-ball-detection-6/test",
            "tennis-ball-detection-6/tennis-ball-detection-6/test")

shutil.move("tennis-ball-detection-6/valid",
            "tennis-ball-detection-6/tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# import shutil

# # Move directories back to their original locations
# shutil.move("tennsi-ball-detection-6/tennsi-ball-detection-6/train",
#             "tennis-ball-detection-6/train")

# shutil.move("tennsi-ball-detection-6/tennsi-ball-detection-6/test",
#             "tennis-ball-detection-6/test")

# shutil.move("tennsi-ball-detection-6/tennsi-ball-detection-6/valid",
#             "tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/valid'

# %%
# !yolo task = detect mode = train model =yolov516u.pt  data ={dataset.location}/data.yaml epochs = 100 imgsz = 640
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ^C
